# %%
from evalResult import eval

# %%
for i in (1,2,3,4):
    print("Part {}:".format(i))
    eval("EN\\dev.out","EN\\dev.p{}.out".format(i))
    print()
# Out:
# Part 1:
#
# #Entity in gold data: 802
# #Entity in prediction: 770
#
# #Correct Entity : 489
# Entity  precision: 0.6351
# Entity  recall: 0.6097
# Entity  F: 0.6221
#
# #Correct Sentiment : 448
# Sentiment  precision: 0.5818
# Sentiment  recall: 0.5586
# Sentiment  F: 0.5700
#
# Part 2:
#
# #Entity in gold data: 802
# #Entity in prediction: 764
#
# #Correct Entity : 508
# Entity  precision: 0.6649
# Entity  recall: 0.6334
# Entity  F: 0.6488
#
# #Correct Sentiment : 447
# Sentiment  precision: 0.5851
# Sentiment  recall: 0.5574
# Sentiment  F: 0.5709
#
# Part 3:
#
# #Entity in gold data: 802
# #Entity in prediction: 741
#
# #Correct Entity : 497
# Entity  precision: 0.6707
# Entity  recall: 0.6197
# Entity  F: 0.6442
#
# #Correct Sentiment : 455
# Sentiment  precision: 0.6140
# Sentiment  recall: 0.5673
# Sentiment  F: 0.5898
#
# Part 4:
#
# #Entity in gold data: 802
# #Entity in prediction: 730
#
# #Correct Entity : 543
# Entity  precision: 0.7438
# Entity  recall: 0.6771
# ...

# %%
for i in (1,2,3,4):
    print("Part {}:".format(i))
    eval("FR\\dev.out","FR\\dev.p{}.out".format(i))
    print()
# Out:
# Part 1:
#
# #Entity in gold data: 238
# #Entity in prediction: 1114
#
# #Correct Entity : 186
# Entity  precision: 0.1670
# Entity  recall: 0.7815
# Entity  F: 0.2751
#
# #Correct Sentiment : 79
# Sentiment  precision: 0.0709
# Sentiment  recall: 0.3319
# Sentiment  F: 0.1169
#
# Part 2:
#
# #Entity in gold data: 238
# #Entity in prediction: 445
#
# #Correct Entity : 136
# Entity  precision: 0.3056
# Entity  recall: 0.5714
# Entity  F: 0.3982
#
# #Correct Sentiment : 76
# Sentiment  precision: 0.1708
# Sentiment  recall: 0.3193
# Sentiment  F: 0.2225
#
# Part 3:
#
# #Entity in gold data: 238
# #Entity in prediction: 73
#
# #Correct Entity : 45
# Entity  precision: 0.6164
# Entity  recall: 0.1891
# Entity  F: 0.2894
#
# #Correct Sentiment : 23
# Sentiment  precision: 0.3151
# Sentiment  recall: 0.0966
# Sentiment  F: 0.1479
#
# Part 4:
#
# #Entity in gold data: 238
# #Entity in prediction: 158
#
# #Correct Entity : 130
# Entity  precision: 0.8228
# Entity  recall: 0.5462
# ...
